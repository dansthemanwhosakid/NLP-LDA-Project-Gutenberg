# %% [markdown]
# ## LDA Text Mining
#
# In natural language processing (NLP), Latent Dirichlet Allocation (LDA) is a popular tool for topic modeling which allows for discovery of patterns in similar topics and semantic structures in a corpus.
#
# We will now generate an LDA model for each of the 1312 books by the top 20 most prolific authors.

# %%
import gensim, spacy, nltk
import pyLDAvis.gensim
import os
import pandas as pd
import re
import gensim.corpora as corpora
# Out:
# /Users/danielkim/opt/anaconda3/lib/python3.7/site-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping

# %% [markdown]
# #### Pre-processing & Preliminary Cleaning
#
# The first step is to clean and process around 1300 English books written by the top 20 most prolific authors from the [University of Michigan Gutenberg Dataset](https://web.eecs.umich.edu/~lahiri/gutenberg_dataset.html) and store it in a dataframe that contains the author's name, book title, and text.

# %%
# %%time

# Processing tools from teammate Bo Cheng:

def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"\'scuse", " excuse ", text)
    text = re.sub(r"\_", " ", text)
    text = re.sub(r"\[|\]", "", text)
    text = re.sub('''\'|\"''', "", text) # remove single and double quotation marks
    text = re.sub(r"\-", " ", text)
    text = re.sub(r'\s+', ' ', text)
    text = text.strip(' ')
    return text

data_path = r'./Gutenberg/txt'

records_dict_list = []

for txt_filename in os.listdir(data_path):
    if txt_filename.endswith(".txt"):
        try:
            author, title = txt_filename.split('.')[0].split('___')
            with open(os.path.join(data_path, txt_filename), "r", encoding="utf-8") as f:
                content = f.read()
            data = {'author': author, 'title': title, 'text': clean_text(content)}
            records_dict_list.append(data)
        except Exception:
            print('not found' + data_path + "/" + txt_filename)
        

df = pd.DataFrame.from_dict(records_dict_list)
# Out:
# CPU times: user 1min 52s, sys: 10.5 s, total: 2min 3s
# Wall time: 2min 23s

# %%
df.head()
# Out:
#                          author  \
# 0  Sir William Schwenck Gilbert
# 1          William Dean Howells
# 2           George Alfred Henty
# 3           George Bernard Shaw
# 4                Hamlin Garland
#
#                                                title  \
# 0                        Bab Ballads and Savoy Songs
# 1  The Editor's Relations With The Young Contributor
# 2                              Bonnie Prince Charlie
# 3                                   Arms and the Man
# 4                           The Spirit of Sweetwater
#
#                                                 text
# 0  bab ballads and savoy songs by w. h. gilbert p...
# 1  literature and life the young contributor by w...
# 2  bonnie prince charlie a tale of fontenoy and c...
# 3  arms and the man by george bernard shaw introd...
# 4  ladies home journal library of fiction the spi...

# %% [markdown]
# ### Filter for Top 20 Most Prolific Authors based on Book Count

# %%
top_20_authors = df['author'].value_counts().nlargest(20).reset_index()
top_20_authors.columns = ['author', 'title_count']
display(top_20_authors.head())

df = df[df['author'].isin(list(top_20_authors['author'].unique()))].reset_index(drop = True)
df.head()
# Out:
#                   author  title_count
# 0  William Wymark Jacobs           97
# 1    George Alfred Henty           89
# 2         R M Ballantyne           88
# 3    Nathaniel Hawthorne           86
# 4   William Dean Howells           84
#                   author                                              title  \
# 0   William Dean Howells  The Editor's Relations With The Young Contributor
# 1    George Alfred Henty                              Bonnie Prince Charlie
# 2     Edward Stratemeyer                                Marching on Niagara
# 3  William Wymark Jacobs               Keeping Watch, Night Watches, Part 2
# 4    George Alfred Henty                                The Tiger of Mysore
#
#                                                 text
# 0  literature and life the young contributor by w...
# 1  bonnie prince charlie a tale of fontenoy and c...
# 2  marching on niagara or the soldier boys of the...
# 3  night watches by w.w. jacobs keeping watch hum...
# 4  the tiger of mysore: a story of the war with t...

# %% [markdown]
# `stop_words.py` contains one function: `custom_stopwords()` that returns a combined list of stopwords from gensim, nltk, spacy, and other sources. **NOTE:** we can continue to add to this stop words list.

# %%
# Import custom stopwords list
from stop_words import custom_stopwords

stop_words = custom_stopwords()

# %% [markdown]
# ### IMPORTANT:
#
# Download spaCy's model by running the following:
#
# `python -m spacy download en_core_web_sm`
#
# Alternative method via pip:
#
# `pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz`
#
# The following function `clean_and_tokenize` prepares the text for LDA modeling.

# %%
########################
#### IMPORTANT!!!! #####
########################
# Download small spacy model!
# !python -m spacy download en_core_web_sm

def clean_and_tokenize(text):
    '''
    Cleans and tokenizes text into corpus of documents that can be fed into an LDA model.
    
    Steps: 
    
    1. Book text is split into sentences based on whether a sentence ends in either an 
    exclamation mark, question mark, or period
    2. Gensim's simple_preprocess lowercases, tokenizes, and de-accents sentences
    3. Stop words are removed
    4. Keep tokens and lemmatize them if their part of speech is either a noun, adj, verb, or adverb
    
    Input: Any book or block of text. For example, df.loc[0,'text'] is the first book in the dataframe
    Returns: Corpus - A list of lists - Each sublist is a tokenized sentence
    '''
    
    raw_book_text = re.split(f"[{re.escape('!.?')}]", text)
    
    nlp = spacy.load('en_core_web_sm', disable = ['parser', 'ner'])

    # Part of speech tagging allowed:
    pos_tagging = ['NOUN', 'ADJ', 'VERB', 'ADV']

    book_text = []
    for sentence in raw_book_text:

        sentence = sentence.strip()
        # Lowercases, tokenizes, de-accents text:
        sentence = gensim.utils.simple_preprocess(sentence, min_len = 2, deacc=True) 

        # Remove stop words by using sets:
        sentence = list(set(sentence).difference(set(stop_words)))

        # Recreate sentence as a string for spaCy processing:
        sentence = nlp(" ".join(sentence))

        # If a token is a noun, adjective, verb, or adverb, keep the token and lemmatize it!
        sentence = [word.lemma_ for word in sentence if word.pos_ in pos_tagging]

        if len(sentence) > 1:
            book_text.append(sentence)
            
    return book_text

# %% [markdown]
# ### Interpret the pyLDAvis visualization:
#
# The Intertopic Distance Map projects topic clusters as circles.
#
# We are using a default PCA model to extract first 2 components (PC1 and PC2) on a topic-term distribution distance matrix. The distance between circles indicates how similar a topic is to one another. The area of the circles is proportional to the proportions of the topics across the total number of tokens in the corpus.
#
# The Top 30 Most Salient Terms represent how relevant and salient terms are for a selected topic.
# 1. The red bars represent the most relevant terms for a selected topic. Relevance rank terms within topics for topic interpretation. The way relevance is defined is by the following [source](https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf):
#
# $$r(w, t | \lambda) = \lambda \cdot P(w|t) + (1 - \lambda) \cdot \frac{P(w|t)}{P(w)}$$
#
# Terms are ranked based on how relevant they are to a given topic and the proportion of their frequency in the topic compared to the rest of the corpus
#
# 2. The blue bars represent the most salient terms for a selected topic. Saliency is defined as how distinctive a term is for a selected topic. For example, we observe the likelihood that an observed word was generated by a topic and the likelihood that any  [source](http://vis.stanford.edu/files/2012-Termite-AVI.pdf)
#
# $$saliency(w) = frequency(w) \cdot \sum_t P(t|w) \cdot \log \frac{P(t|w)}{P(t)}$$

# %% [markdown]
# Generating 1300+ LDA models:
#
# I referenced the following [source](https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#11createthedictionaryandcorpusneededfortopicmodeling) to generate the id2word and corpus for topic modeling.

# %%
# If the folder that stores the author's ldas doesn't exist, create it
if os.path.isdir('./data/LDA_htmls/ALL_LDA_htmls') == False:
    print("The folder ALL_LDA_htmls has been created: ./data/LDA_htmls/ALL_LDA_htmls")
    os.mkdir('./data/LDA_htmls/ALL_LDA_htmls')
else:
    print("Folder ALL_LDA_htmls already exists")
# Out:
# The folder ALL_LDA_htmls has been created: ./data/LDA_htmls/ALL_LDA_htmls

# %%
# %%time
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# Top 20 Most Prolific Authors
authors = df['author'].unique()

# Loop through top 20 authors
for author in authors:
    
    # Create an author mask to filter dataframe
    auth_mask = (df['author'] == author)
    
    # Grab books per selected author
    books_per_auth = df[auth_mask]['title']
    
    # Convert author name to lower and replace spaces
    auth_file_name = author.lower().replace(' ','_')
    
    # Create the author's folder in ALL_LDA_htmls:
    os.mkdir(f"./data/LDA_htmls/ALL_LDA_htmls/{auth_file_name}")
    
    print(f"Currently processing {author}'s works:")
    print("*********************************************")
    
    # Loop through each author's book and create an LDA html
    for book in books_per_auth:
        
        book_mask = (df['title'] == book)
        
        book_file_name = book.lower().replace(" ","_")
        book_file_name = re.sub('[^a-z0-9\\_]', '', book_file_name)
        
        # Grab author's specific book's tokenized text data
        raw_data = df[auth_mask & book_mask]['text'].values[0]
        
        # Process text data:
        text_data = clean_and_tokenize(raw_data)
        
        # Create Dictionary: (bag of words)
        id2word = corpora.Dictionary(text_data)
        
        # Print total words for author's book:
        print(f"{book} has a total of {len(id2word)} words")
        
        # Convert document into bag of words format
        corpus = [id2word.doc2bow(text) for text in text_data]
        
        # LDA model
        LDA = gensim.models.ldamodel.LdaModel(corpus = corpus,
                                              id2word = id2word,
                                              num_topics = 5, # Choosing 5 topics
                                              random_state=42,
                                              update_every = 2, # online iterative learning instead of batch
                                              chunksize = 100,
                                              passes = 5,
                                              alpha = 'auto',
                                              per_word_topics = True)
        
        # Generate top 10 topics
        lda_topics = LDA.print_topics()
        
        # Save pyLDAvis visualization as an html file:
        viz = pyLDAvis.gensim.prepare(LDA, corpus, dictionary = LDA.id2word)
        pyLDAvis.save_html(viz, f"./data/LDA_htmls/ALL_LDA_htmls/{auth_file_name}/{book_file_name}.html")
        
    print(' ')
# Out:
# Currently processing William Dean Howells's works:
# *********************************************
# The Editor's Relations With The Young Contributor has a total of 618 words
# A Chance Acquaintance has a total of 4170 words
# The March Family Trilogy has a total of 10871 words
# The Quality of Mercy has a total of 4855 words
# Christmas Every Day and Other Stories has a total of 1153 words
# A Little Swiss Sojourn has a total of 2172 words
# Dr has a total of 3411 words
# Between The Dark And The Daylight has a total of 3359 words
# Poems has a total of 2756 words
# The Albany Depot has a total of 643 words
# The Landlord at Lion's Head has a total of 4579 words
# Last Days in a Dutch Hotel has a total of 789 words
# A Pair of Patient Lovers has a total of 4187 words
# Suburban Sketches has a total of 5372 words
# Their Wedding Journey has a total of 5414 words
# My Mark Twain has a total of 2774 words
# Fennel and Rue has a total of 2493 words
# A Foregone Conclusion has a total of 4014 words
# The Leatherwood God has a total of 2983 words
# Roundabout to Boston has a total of 943 words
# A Traveler from Altruria has a total of 3773 words
# Cambridge Neighbors has a total of 1551 words
# Imaginary Interviews has a total of 6405 words
# The Minister's Charge has a total of 4944 words
# Indian Summer has a total of 4691 words
# A Likely Story has a total of 732 words
# The Daughter of the Storage has a total of 4034 words
# The Man of Letters as a Man of Business has a total of 1349 words
# The White Mr has a total of 1407 words
# Staccato Notes of a Vanished Summer has a total of 687 words
# Literature and Life has a total of 8325 words
# Modern Italian Poets has a total of 5846 words
# Seven English Cities has a total of 4490 words
# Roman Holidays and Others has a total of 6235 words
# Literary Boston has a total of 1259 words
# American Literary Centers has a total of 525 words
# April Hopes has a total of 5028 words
# Bride Roses has a total of 442 words
# Short Stories and Essays has a total of 4604 words
# First Visit to New England and Others has a total of 2500 words
# The Confessions of a Summer Colonist has a total of 1059 words
# The Garotters has a total of 842 words
# The Elevator has a total of 689 words
# A Fearful Responsibility and Other Stories has a total of 3630 words
# Their Silver Wedding Journey has a total of 6715 words
# Venetian Life has a total of 7132 words
# Buying a Horse has a total of 1027 words
# Familiar Spanish Travels has a total of 6319 words
# The Parlor-Car has a total of 681 words
# Studies of Lowell has a total of 1475 words
# Oliver Wendell Holmes has a total of 1266 words
# Annie Kilburn has a total of 4195 words
# Boy Life has a total of 2837 words
# The Lady of the Aroostook has a total of 4087 words
# A Boy's Town has a total of 4264 words
# Emile Zola has a total of 683 words
# The Rise of Silas Lapham has a total of 4813 words
# The Coast of Bohemia has a total of 3627 words
# The Sleeping Car has a total of 692 words
# Of Literature has a total of 10397 words
# A Psychological Counter-current in Recent Fiction has a total of 1048 words
# Ragged Lady has a total of 3941 words
# Stories Of Ohio has a total of 3995 words
# The Kentons has a total of 3683 words
# The Register has a total of 832 words
# An Open-Eyed Conspiracy; An Idyl of Saratoga has a total of 2628 words
# Some Anomalies of the Short Story has a total of 688 words
# A Hazard of New Fortunes has a total of 6424 words
# Italian Journeys has a total of 6594 words
# The Flight of Pony Baker has a total of 1543 words
# A Belated Guest has a total of 885 words
# Criticism And Fiction has a total of 2841 words
# London Films has a total of 5434 words
# Henry James, Jr has a total of 589 words
# Through the Eye of the Needle has a total of 3924 words
# Five O'Clock Tea has a total of 506 words
# A Modern Instance has a total of 6124 words
# My Literary Passions has a total of 3626 words
# The Story of a Play has a total of 3299 words
# Spanish Prisoners of War has a total of 751 words
# Literary Friends And Acquaintances has a total of 6164 words
# Evening Dress has a total of 669 words
# Questionable Shapes has a total of 2862 words
# The Standard Household-Effect Company has a total of 573 words
#
# Currently processing George Alfred Henty's works:
# *********************************************
# Bonnie Prince Charlie has a total of 3917 words
# The Tiger of Mysore has a total of 4223 words
# Wulf the Saxon has a total of 4373 words
# Jack Archer has a total of 4211 words
# Facing Death has a total of 3470 words
# In The Heart Of The Rockies has a total of 3347 words
# The Curse of Carne's Hold has a total of 3733 words
# With Moore At Corunna has a total of 4157 words
# With Kitchener in the Soudan has a total of 4296 words
# The Boy Knight has a total of 4273 words
# For Name and Fame has a total of 3937 words
# The Lion of the North has a total of 4425 words
# Sturdy and Strong has a total of 3096 words
# The Lost Heir has a total of 3859 words
# The Queen's Cup has a total of 3464 words
# Rujub, the Juggler has a total of 4432 words
# The Cat of Bubastes has a total of 4593 words
# In Freedom's Cause has a total of 4365 words
# The Cornet of Horse has a total of 4374 words
# Friends, though divided has a total of 4331 words
# In Times of Peril has a total of 4213 words
# In the Irish Brigade has a total of 4261 words
# March to Magdala has a total of 5451 words
# Tales of Daring and Danger has a total of 3003 words
# The Bravest of the Brave has a total of 3948 words
# For the Temple has a total of 4161 words
# The Lion of Saint Mark has a total of 4052 words
# With Wolfe in Canada has a total of 4249 words
# True to the Old Flag has a total of 3904 words
# The Dash for Khartoum has a total of 4687 words
# Maori and Settler has a total of 3811 words
# In the Hands of the Malays, and Other Stories has a total of 2316 words
# The Young Carthaginian has a total of 4715 words
# Through Three Campaigns has a total of 4105 words
# Through Russian Snows has a total of 4127 words
# With Clive in India has a total of 4434 words
# Under Wellington's Command has a total of 4067 words
# Winning His Spurs has a total of 4271 words
# On the Irrawaddy has a total of 3701 words
# Dorothy's Double, Volume 2 has a total of 2232 words
# One of the 28th has a total of 4143 words
# Captain Bayley's Heir has a total of 4847 words
# The Young Colonists has a total of 3555 words
# By Conduct and Courage has a total of 4547 words
# Dorothy's Double, Volume 3 has a total of 2130 words
# With Cochrane the Dauntless has a total of 4375 words
# On the Pampas has a total of 3889 words
# Dorothy's Double, Volume 1 has a total of 2354 words
# A Girl of the Commune has a total of 4666 words
# Both Sides the Border has a total of 4061 words
# Under Drake's Flag has a total of 4691 words
# A Search For A Secret, a Novel, Volume 2 has a total of 2842 words
# Won by the Sword has a total of 4275 words
# With Lee in Virginia has a total of 4101 words
# A March on London has a total of 4039 words
# With Buller in Natal has a total of 3783 words
# When London Burned has a total of 4354 words
# The Golden Canyon has a total of 2107 words
# A Final Reckoning has a total of 3427 words
# Out on the Pampas has a total of 3904 words
# A Search For A Secret, a Novel, Volume 3 has a total of 2743 words
# A Search For A Secret, a Novel, Volume 1 has a total of 3511 words
# By Right of Conquest has a total of 4972 words
# By Pike and Dyke:  A Tale of the Rise of the Dutch Republic has a total of 4519 words
# By England's Aid or The Freeing of the Netherlands (1585-1604) has a total of 4433 words
# The Young Franc Tireurs has a total of 3977 words
# Beric the Briton has a total of 4758 words
# Among Malay Pirates has a total of 3329 words
# The Dragon and the Raven has a total of 3739 words
# Saint Bartholomew's Eve has a total of 4559 words
# No Surrender! has a total of 3780 words
# Orange and Green has a total of 3794 words
# Held Fast For England has a total of 3838 words
# With Frederick the Great has a total of 4321 words
# Saint George for England has a total of 4311 words
# Condemned as a Nihilist has a total of 4629 words
# The Young Buglers has a total of 4138 words
# At the Point of the Bayonet has a total of 4125 words
# A Knight of the White Cross has a total of 4620 words
# At Agincourt has a total of 4144 words
# In the Reign of Terror has a total of 3613 words
# A Roving Commission has a total of 4100 words
# The Treasure of the Incas has a total of 3880 words
# A Chapter of Adventures has a total of 2799 words
# By Sheer Pluck has a total of 4296 words
# Colonel Thorndyke's Secret has a total of 3932 words
# At Aboukir and Acre has a total of 3962 words
# A Jacobite Exile has a total of 4026 words
# Through the Fray has a total of 3918 words
#
# Currently processing Edward Stratemeyer's works:
# *********************************************
# Marching on Niagara has a total of 2818 words
# First at the North Pole has a total of 2720 words
# Guns And Snowshoes has a total of 2228 words
# The Rover Boys at Colby Hall has a total of 2739 words
# The Rover Boys on Snowshoe Island has a total of 2562 words
# Richard Dare's Venture has a total of 2298 words
# The Rover Boys in the Jungle has a total of 2383 words
# The Rover Boys in Camp has a total of 2425 words
# The Rover Boys out West has a total of 2419 words
# The Young Bridge-Tender has a total of 2352 words
# Dave Porter and His Double has a total of 2476 words
# The Rover Boys in Business has a total of 2382 words
# At the Fall of Port Arthur has a total of 2566 words
# The Campaign of the Jungle has a total of 2944 words
# The Boy Land Boomer has a total of 2358 words
# The Rover Boys at College has a total of 2372 words
# Dave Porter and the Runaways has a total of 2467 words
# The Rover Boys on the Great Lakes has a total of 2113 words
# The Rover Boys on Land and Sea has a total of 2200 words
# Young Auctioneers has a total of 2657 words
# Leo the Circus Boy has a total of 2380 words
# On the Trail of Pontiac has a total of 2742 words
# Dave Porter in the Gold Fields has a total of 2506 words
# American Boy's Life of Theodore Roosevelt has a total of 3331 words
# The Rover Boys on the Ocean has a total of 2202 words
# The Rover Boys on a Tour has a total of 2595 words
# The Rover Boys in Alaska has a total of 2455 words
# To Alaska for Gold has a total of 2787 words
# The Rover Boys on the River has a total of 2217 words
# True to Himself has a total of 2548 words
# Young Hunters of the Lake has a total of 2278 words
# Dave Porter in the South Seas has a total of 2632 words
# The Missing Tin Box has a total of 2047 words
# The Young Oarsmen of Lakeview has a total of 2538 words
# The Last Cruise of the Spitfire has a total of 2235 words
# Boys of The Fort has a total of 2251 words
# Dave Porter on Cave Island has a total of 2354 words
# The Rover Boys at School has a total of 2408 words
# Four Boy Hunters has a total of 2154 words
# The Rover Boys at Big Horn Ranch has a total of 2689 words
# The Rover Boys in the Land of Luck has a total of 2726 words
# Dave Porter At Bear Camp has a total of 2407 words
# The Rover Boys in the Air has a total of 2551 words
# The Rover Boys on a Hunt has a total of 2614 words
# The Rover Boys in Southern Waters has a total of 2243 words
# The Rover Boys on Treasure Isle has a total of 2531 words
# Dave Porter in the Far North has a total of 2715 words
# The Rover Boys In The Mountains has a total of 2360 words
# Dave Porter at Star Ranch has a total of 2585 words
# The Rover Boys on the Farm has a total of 2447 words
# Dave Porter and His Rivals has a total of 2590 words
# For the Liberty of Texas has a total of 2762 words
# The Rover Boys on the Plains has a total of 2291 words
# Out with Gun and Camera has a total of 2298 words
# The Rover Boys in New York has a total of 2278 words
# Fighting in Cuban Waters has a total of 3238 words
# Three Young Ranchmen has a total of 2205 words
# The Mystery at Putnam Hall has a total of 2323 words
#
# Currently processing William Wymark Jacobs's works:
# *********************************************
# Keeping Watch, Night Watches, Part 2 has a total of 379 words
# Dual Control, Ship's Company, Part 8 has a total of 478 words
# Short Cruises has a total of 2785 words
# Manners Makyth Man, Ship's Company, Part 12 has a total of 431 words
# The Vigil, Night Watches, Part 8 has a total of 433 words
# Salthaven has a total of 3426 words
# The Head of The Family, Sailor's Knots, Part 9 has a total of 557 words
# At Sunwich Port has a total of 3924 words
# Skilled Assistance, Ship's Company, Part 9 has a total of 368 words
# Sea Urchins has a total of 3187 words
# Establishing Relations, Odd Craft, Part 7 has a total of 588 words
# The Persecution of Bob Pretty, Odd Craft, Part 9 has a total of 418 words
# Striking Hard, Deep Waters, Part 10 has a total of 635 words
# Night Watches has a total of 2156 words
# Odd Charges, Odd Craft, Part 13 has a total of 413 words
# Sentence Deferred, Sailor's Knots, Part 4 has a total of 592 words
# The White Cat, Captains All, Book 10 has a total of 383 words
# Blundell's Improvement, Odd Craft, Part 3 has a total of 590 words
# Double Dealing, Sailor's Knots, Part 11 has a total of 491 words
# The Well, The Lady of the Barge and Others, Part 4 has a total of 615 words
# In The Library, The Lady of the Barge and Others, Part 6 has a total of 535 words
# Peter's Pence, Sailor's Knots, Part 8 has a total of 364 words
# The Skipper’s Wooing, and The Brown Man’s Servant has a total of 3054 words
# Captains All has a total of 2409 words
# The Boatswain's Mate, Captains All, Book 2 has a total of 706 words
# The Castaway, Odd Craft, Part 2 has a total of 573 words
# Fine Feathers, Ship's Company, Part 1 has a total of 567 words
# A Golden Venture, The Lady of the Barge and Others, Part 11 has a total of 521 words
# Light Freights has a total of 2820 words
# Family Cares, Deep Waters, Part 7 has a total of 449 words
# Captains All, Part 1 has a total of 419 words
# More Cargoes has a total of 3209 words
# Bill's Lapse, Odd Craft, Part 4 has a total of 423 words
# Made to Measure, Deep Waters, Part 3 has a total of 460 words
# Self-Help, Sailor's Knots, Part 4 has a total of 405 words
# The Substitute, Deep Waters, Part 9 has a total of 432 words
# Shareholders, Deep Waters, Part 1 has a total of 397 words
# Breaking A Spell, Odd Craft, Part 6 has a total of 362 words
# Lady of the Barge, Lady of the Barge and Others, Part 1 has a total of 624 words
# Back to Back, Night Watches, Part 1 has a total of 548 words
# Stepping Backwards, Night Watches, Part 5 has a total of 444 words
# Friends In Need, Ship's Company, Part 2 has a total of 520 words
# The Three Sisters, Night Watches, Part 6 has a total of 568 words
# Husbandry, Deep Waters, Part 6 has a total of 446 words
# A Tiger's Skin, The Lady of the Barge and Others, Part 8 has a total of 449 words
# Three at Table, The Lady of the Barge and Others, Part 12 has a total of 463 words
# The Weaker Vessel, Night Watches, Part 4 has a total of 589 words
# Bob's Redemption, Captains All, Book 5 has a total of 427 words
# Easy Money, Night Watches, Part 9 has a total of 330 words
# A Spirit of Avarice, Odd Craft, Part 11 has a total of 699 words
# Lawyer Quince, Odd Craft, Part 5 has a total of 629 words
# Ship's Company has a total of 2527 words
# The Money Box, Odd Craft, Part 1 has a total of 425 words
# Deep Waters has a total of 2426 words
# Paying Off, Deep Waters, Part 2 has a total of 336 words
# His Other Self, Night Watches, Part 10 has a total of 363 words
# Many Cargoes has a total of 3880 words
# Cupboard Love, The Lady of the Barge and Others, Part 5 has a total of 532 words
# A Mixed Proposal, The Lady of the Barge and Others, Part 9 has a total of 629 words
# The Monkey's Paw, The Lady of the Barge and Others, Part 2 has a total of 593 words
# The Third String, Odd Craft, Part 12 has a total of 441 words
# The Changing Numbers, Odd Craft, Part 8 has a total of 626 words
# The Constable's Move, Captains All, Book 4 has a total of 645 words
# Dixon's Return, Odd Craft, Part 10 has a total of 379 words
# The Bequest, Ship's Company, Part 6 has a total of 458 words
# Four Pigeons, Captains All, Book 7 has a total of 383 words
# The Guardian Angel, Ship's Company, Part 7 has a total of 407 words
# For Better or Worse, Ship's Company, Part 10 has a total of 429 words
# Watch-Dogs, Ship's Company, Part 5 has a total of 381 words
# Fairy Gold, Ship's Company, Part 4 has a total of 566 words
# Keeping Up Appearances, Sailor's Knots, Part 12 has a total of 392 words
# Prize Money, Sailor's Knots, Part 10 has a total of 361 words
# Homeward Bound, Sailor's Knots, Part 2 has a total of 549 words
# Admiral Peters, Odd Craft, Part 14 has a total of 614 words
# Sam's Ghost, Deep Waters, Part 4 has a total of 376 words
# A Master of Craft has a total of 3798 words
# Bedridden and The Winter Offensive, Deep Waters, Part 8 has a total of 555 words
# The Temptation of Samuel Burge, Captains All, Book 8 has a total of 643 words
# Matrimonial Openings, Sailor's Knots, Part 5 has a total of 469 words
# The Toll-House, Sailor's Knots, Part 7 has a total of 529 words
# Over The Side, Captains All, Book 6 has a total of 437 words
# Good Intentions, Ship's Company, Part 3 has a total of 391 words
# The Nest Egg, Captains All, Book 3 has a total of 395 words
# An Adulteration Act, The Lady of the Barge and Others, Part 10 has a total of 565 words
# Dialstone Lane has a total of 3621 words
# The Understudy, Night Watches, Part 3 has a total of 321 words
# The Convert, Deep Waters, Part 5 has a total of 635 words
# Dirty Work, Deep Waters, Part 11 has a total of 479 words
# Deserted, Sailor's Knots, Part 1 has a total of 477 words
# Odd Man Out, Sailor's Knots, Part 6 has a total of 338 words
# The Madness of Mr has a total of 543 words
# The Lady of the Barge has a total of 3100 words
# The Old Man of the Sea, Ship's Company, Part 11 has a total of 493 words
# Odd Craft has a total of 3059 words
# The Unknown, Night Watches, Part 7 has a total of 332 words
# Bill's Paper Chase, Lady of the Barge and Others, Part 3 has a total of 350 words
# Captain Rogers, The Lady of the Barge and Others, Part 7 has a total of 658 words
#
# Currently processing Henry Rider Haggard's works:
# *********************************************
# Queen Sheba's Ring has a total of 4569 words
# Child of Storm has a total of 3720 words
# She has a total of 5154 words
# Love Eternal has a total of 4830 words
# Maiwa's Revenge has a total of 2414 words
# Hunter Quatermain's Story has a total of 896 words
# The Virgin of the Sun has a total of 3654 words
# Elissa has a total of 2763 words
# Ayesha has a total of 4925 words
# Swallow has a total of 3409 words
# Red Eve has a total of 3726 words
# The Yellow God has a total of 4220 words
# The Brethren has a total of 3856 words
# Finished has a total of 4356 words
# Allan Quatermain has a total of 5265 words
# Doctor Therne has a total of 3507 words
# Cleopatra has a total of 3852 words
# Pearl-Maiden has a total of 4661 words
# Nada the Lily has a total of 2781 words
# Mr has a total of 3722 words
# The People Of The Mist has a total of 5195 words
# Cetywayo and his White Neighbours has a total of 5298 words
# Long Odds has a total of 853 words
# Eric Brighteyes has a total of 2895 words
# Colonel Quaritch, V has a total of 4893 words
# Beatrice has a total of 4627 words
# The Wanderer's Necklace has a total of 3250 words
# Jess has a total of 4804 words
# Lysbeth has a total of 5731 words
# King Solomon's Mines has a total of 4238 words
# Allan and the Holy Flower has a total of 4753 words
# She and Allan has a total of 4746 words
# Fair Margaret has a total of 3887 words
# Benita, An African Romance has a total of 3522 words
# The Wizard has a total of 2816 words
# Allan's Wife has a total of 2879 words
# The Lady Of Blossholme has a total of 3840 words
# Stella Fregelius has a total of 4779 words
# The Ancient Allan has a total of 3491 words
# Black Heart and White Heart has a total of 1860 words
# Smith and the Pharaohs, and Other Tales has a total of 4320 words
# The Ivory Child has a total of 4746 words
# When the World Shook has a total of 5218 words
# Marie has a total of 4030 words
# Dawn has a total of 6574 words
# Moon of Israel has a total of 2905 words
# Morning Star has a total of 3126 words
# The Mahatma and the Hare has a total of 1627 words
# Regeneration has a total of 3778 words
# Montezuma's Daughter has a total of 4566 words
# The Ghost Kings has a total of 4075 words
# A Tale of Three Lions has a total of 1280 words
#
# Currently processing Sir Arthur Conan Doyle's works:
# *********************************************
# The Refugees has a total of 5235 words
# The Great Keinplatz Experiment and Other Tales of Twilight and the Unseen has a total of 4476 words
# Danger! and Other Stories has a total of 4140 words
# The Exploits Of Brigadier Gerard has a total of 3527 words
# The Green Flag has a total of 4602 words
# Sir Nigel has a total of 5270 words
# Round the Red Lamp has a total of 4443 words
# A Visit to Three Fronts has a total of 1757 words
# The Adventures of Gerard has a total of 3346 words
# The Disappearance of Lady Frances Carfax has a total of 962 words
# The Adventure of the Bruce-Partington Plans has a total of 1131 words
# The Tragedy of The Korosko has a total of 3333 words
# The Poison Belt has a total of 2812 words
# The Last of the Legions and Other Tales of Long Ago has a total of 3449 words
# The Last Galley has a total of 4829 words
# The Crime of the Congo has a total of 3473 words
# The Great Boer War has a total of 7096 words
# The Adventures of Sherlock Holmes has a total of 4694 words
# A Desert Drama has a total of 3360 words
# The Captain of the Pole-Star and Other Tales has a total of 5499 words
# Uncle Bernac has a total of 3589 words
# Songs of Action has a total of 1173 words
# The Croxley Master has a total of 1701 words
# Through the Magic Door has a total of 4127 words
# The Cabman's Story has a total of 415 words
# The Adventure of the Dying Detective has a total of 771 words
# The White Company has a total of 5946 words
# The Valley of Fear has a total of 3282 words
# Songs Of The Road has a total of 1379 words
# The Mystery of Cloomber has a total of 3814 words
# The Adventure of the Cardboard Box has a total of 959 words
# The Return of Sherlock Holmes has a total of 4794 words
# The Adventure of the Red Circle has a total of 831 words
# Tales of Terror and Mystery has a total of 4645 words
# The Vital Message has a total of 2770 words
# His Last Bow has a total of 808 words
# The Dealings of Captain Sharkey and Other Tales of Pirates has a total of 4589 words
# Rodney Stone has a total of 4459 words
# Micah Clarke has a total of 7353 words
# The Parasite has a total of 1669 words
# Beyond the City has a total of 2869 words
# The Guards Came Through and Other Poems has a total of 1018 words
# The Great Shadow and Other Napoleonic Tales has a total of 2755 words
# The Adventure of Wisteria Lodge has a total of 1305 words
# Memoirs of Sherlock Holmes has a total of 4266 words
# The Sign of the Four has a total of 3122 words
# The Doings Of Raffles Haw has a total of 3001 words
# The War in South Africa has a total of 3839 words
# The Lost World has a total of 4698 words
# A Duet has a total of 3823 words
# The New Revelation has a total of 1984 words
# The Hound of the Baskervilles has a total of 3305 words
# The Firm of Girdlestone has a total of 6607 words
# The Man from Archangel has a total of 4709 words
# My Friend The Murderer has a total of 931 words
# The Adventure of the Devil's Foot has a total of 1207 words
# A Study In Scarlet has a total of 3434 words
#
# Currently processing Henry James's works:
# *********************************************
# A Small Boy and Others has a total of 6732 words
# Embarrassments has a total of 3932 words
# The Bostonians, Volume 2 has a total of 4409 words
# The Wings of the Dove, Volume 1 has a total of 4136 words
# Pandora has a total of 2057 words
# The Madonna of the Future has a total of 1954 words
# The Author Of Beltraffio has a total of 1815 words
# The Bostonians, Volume 1 has a total of 4559 words
# The Pension Beaurepas has a total of 1669 words
# The Wings of the Dove, Volume 2 has a total of 4255 words
# Eugene Pickering has a total of 2012 words
# Notes of a Son and Brother has a total of 7356 words
# The Golden Bowl has a total of 6634 words
# Picture and Text has a total of 3196 words
# The Pupil has a total of 1873 words
# Sir Dominick Ferrand has a total of 2320 words
# The Altar of the Dead has a total of 1584 words
# Nona Vincent has a total of 1334 words
# The Portrait of a Lady, Volume 2 has a total of 4485 words
# The Patagonia has a total of 1757 words
# The Path Of Duty has a total of 1360 words
# Roderick Hudson has a total of 6025 words
# The Portrait of a Lady, Volume 1 has a total of 5061 words
# A  Passionate Pilgrim has a total of 2948 words
# The Sacred Fount has a total of 3560 words
# Georgina's Reasons has a total of 2115 words
# Glasses has a total of 1984 words
# The Finer Grain has a total of 4096 words
# The Aspern Papers has a total of 2670 words
# The Letters of Henry James, Volume 2 has a total of 7144 words
# The Europeans has a total of 3294 words
# The Ambassadors has a total of 5753 words
# The Outcry has a total of 3247 words
# The Real Thing has a total of 1312 words
# The Letters of Henry James, Volume 1 has a total of 7096 words
# Greville Fane has a total of 1056 words
# Four Meetings has a total of 1072 words
# The Coxon Fund has a total of 2273 words
# The Point of View has a total of 1919 words
# The Reverberator has a total of 3273 words
# The Lesson of the Master has a total of 2111 words
# Some Short Stories has a total of 3078 words
# What Maisie Knew has a total of 4489 words
# Washington Square has a total of 3379 words
# An International Episode has a total of 1998 words
# Italian Hours has a total of 7884 words
# The Middle Years has a total of 2576 words
# The Spoils of Poynton has a total of 3825 words
# The Death of the Lion has a total of 1753 words
# Louisa Pallant has a total of 1536 words
# The American has a total of 5392 words
# The Turn of the Screw has a total of 2888 words
# A London Life and Other Tales has a total of 4466 words
# In the Cage has a total of 2710 words
# The Jolly Corner has a total of 1732 words
# The Diary of a Man of Fifty has a total of 988 words
# Lady Barbarina has a total of 6368 words
# The Chaperon has a total of 1665 words
# The Figure in the Carpet has a total of 1629 words
# The Beldonald Holbein has a total of 937 words
# Confidence has a total of 3553 words
# The Tragic Muse has a total of 7284 words
# Madame de Mauves has a total of 2987 words
# A Little Tour in France, Version 2 has a total of 5461 words
# The Marriages has a total of 1395 words
# The Awkward Age has a total of 4650 words
# Daisy Miller has a total of 1685 words
# A Bundle of Letters has a total of 1351 words
# The Beast in the Jungle has a total of 1651 words
# Within the Rim and Other Essays has a total of 2348 words
# Hawthorne has a total of 4292 words
# A Little Tour in France, Version 1 has a total of 5223 words
#
# Currently processing Bret Harte's works:
# *********************************************
# A Waif of the Plains has a total of 3471 words
# Colonel Starbottle's Client and Other Stories has a total of 4521 words
# Sally Dows and Other Stories has a total of 4510 words
# Openings in the Old Trail has a total of 4751 words
# The Argonauts of North Liberty has a total of 3184 words
# Susy, A Story of the Plains has a total of 4052 words
# In the Carquinez Woods has a total of 3279 words
# Flip, A California Romance has a total of 2109 words
# Tennessee's Partner has a total of 950 words
# Thankful Blossom has a total of 2216 words
# The Three Partners has a total of 4187 words
# Two Men of Sandy Bar has a total of 2235 words
# New Burlesques has a total of 3041 words
# Gabriel Conroy has a total of 7060 words
# Excelsior has a total of 88 words
# Tales of Trail and Town has a total of 4908 words
# A Sappho of Green Springs has a total of 4215 words
# A Millionaire of Rough-and-Ready has a total of 2704 words
# Drift from Two Shores has a total of 4896 words
# Complete Poetical Works of Bret Harte has a total of 4345 words
# The Story of a Mine has a total of 3710 words
# Urban Sketches has a total of 3036 words
# By Shore and Sedge has a total of 3679 words
# Condensed Novels has a total of 3582 words
# Found At Blazing Star has a total of 1676 words
# Devil's Ford has a total of 2656 words
# In a Hollow of the Hills has a total of 3294 words
# Jeff Briggs's Love Story has a total of 2553 words
# Stories in Light and Shadow has a total of 4752 words
# From Sand Hill to Pine has a total of 4326 words
# Salomy Jane has a total of 1075 words
# The Bell-Ringer of Angel's and Other Stories has a total of 4965 words
# A Ward of the Golden Gate has a total of 3708 words
# Maruja has a total of 3459 words
# A Protegee of Jack Hamlin's and Other Stories has a total of 4454 words
# Cressy has a total of 4433 words
# A First Family of Tasajara has a total of 4322 words
# Tales of the Argonauts has a total of 4948 words
# Frontier Stories has a total of 6977 words
# Mr has a total of 4250 words
# The Queen of the Pirate Isle has a total of 1080 words
# Her Letter His Answer & Her Last Letter has a total of 379 words
# Under the Redwoods has a total of 5160 words
# Legends and Tales has a total of 2505 words
# Snow-Bound at Eagle's has a total of 2972 words
# A Phyllis of the Sierras has a total of 3064 words
# Selected Stories has a total of 7541 words
# The Twins of Table Mountain and Other Stories has a total of 3906 words
# East and West has a total of 1815 words
# Dickens in Camp has a total of 359 words
# The Crusade of the Excelsior has a total of 5004 words
# The Heritage of Dedlow Marsh and Other Tales has a total of 4370 words
# A Drift from Redwood Camp has a total of 1440 words
# On the Frontier has a total of 3874 words
# Clarence has a total of 3890 words
# The Luck of Roaring Camp and Other Tales has a total of 8010 words
# Trent's Trust and Other Stories has a total of 5313 words
# Mrs has a total of 3911 words
#
# Currently processing Nathaniel Hawthorne's works:
# *********************************************
# Fancy's Show-Box (From "Twice Told Tales") has a total of 470 words
# An Old Woman's Tale has a total of 781 words
# The Vision of the Fountain (From "Twice Told Tales") has a total of 388 words
# Passages from the French and Italian Notebooks, Complete has a total of 7280 words
# The Miraculous Pitcher has a total of 1025 words
# A Virtuoso's Collection (From "Mosses From An Old Manse") has a total of 1044 words
# Edward Fane's Rosebud (From "Twice Told Tales") has a total of 589 words
# Sketches from Memory (From "Mosses From An Old Manse") has a total of 1162 words
# The Sister Years (From "Twice Told Tales") has a total of 581 words
# Biographical Sketches has a total of 2483 words
# The Old Manse (From "Mosses From An Old Manse") has a total of 1848 words
# Sketches from Memory has a total of 558 words
# The New Adam and Eve (From "Mosses From An Old Manse") has a total of 1245 words
# Twice Told Tales has a total of 7437 words
# The White Old Maid (From "Twice Told Tales") has a total of 726 words
# The Gorgon's Head has a total of 1242 words
# Time's Portraiture has a total of 620 words
# A Select Party (From "Mosses From An Old Manse") has a total of 1086 words
# Tanglewood Tales has a total of 3749 words
# A Book of Autographs has a total of 1022 words
# The Dolliver Romance has a total of 2363 words
# Old Ticonderoga, A Picture of The Past has a total of 450 words
# The Threefold Destiny (From "Twice Told Tales") has a total of 668 words
# Beneath an Umbrella (From "Twice Told Tales") has a total of 602 words
# The Scarlet Letter has a total of 5435 words
# Monsieur du Muroir (From "Mosses From An Old Manse") has a total of 859 words
# The House of the Seven Gables has a total of 6297 words
# The Haunted Mind (From "Twice Told Tales") has a total of 460 words
# Passages from the American Notebooks, Volume 2 has a total of 4643 words
# Other Tales and Sketches has a total of 1637 words
# Sights from a Steeple (From "Twice Told Tales") has a total of 654 words
# Our Old Home has a total of 7495 words
# A Bell's Biography has a total of 550 words
# True Stories from History and Biography has a total of 4164 words
# Earth's Holocaust (From "Mosses From An Old Manse") has a total of 1449 words
# A Rill from the Town Pump (From "Twice Told Tales") has a total of 575 words
# Passages from the American Notebooks, Volume 1 has a total of 4855 words
# The Toll Gatherer's Day (From "Twice Told Tales") has a total of 583 words
# P has a total of 1277 words
# Buds and Bird Voices (From "Mosses From An Old Manse") has a total of 749 words
# Grandfather's Chair has a total of 3677 words
# A Wonder Book for Girls & Boys has a total of 3216 words
# Chippings With A Chisel (From "Twice Told Tales") has a total of 775 words
# The Intelligence Office (From "Mosses From An Old Manse") has a total of 1020 words
# Old News has a total of 1709 words
# Dr has a total of 804 words
# John Inglefield's Thanksgiving has a total of 340 words
# The Christmas Banquet (From "Mosses From An Old Manse") has a total of 1255 words
# Passages from a Relinquished Work (From "Mosses From An Old Manse") has a total of 1106 words
# Little Daffydowndilly has a total of 392 words
# The Lily's Quest (From "Twice Told Tales") has a total of 483 words
# The Paradise of Children has a total of 807 words
# Main Street has a total of 1699 words
# The Blithedale Romance has a total of 5542 words
# The Snow Image has a total of 3256 words
# Sylph Etherege has a total of 518 words
# Footprints on the Sea-Shore (From "Twice Told Tales") has a total of 775 words
# The Marble Faun, Volume 2 has a total of 5316 words
# The Ancestral Footstep (fragment) has a total of 2601 words
# A Wonder Book and Tanglewood Tales has a total of 4897 words
# The Village Uncle (From "Twice Told Tales") has a total of 888 words
# Little Annie's Ramble (From "Twice Told Tales") has a total of 608 words
# Little Masterpieces has a total of 3712 words
# The Prophetic Pictures (From "Twice Told Tales") has a total of 900 words
# The Marble Faun, Volume 1 has a total of 4686 words
# The Wives of The Dead has a total of 549 words
# The Man of Adamant has a total of 576 words
# Sketches and Studies has a total of 5230 words
# Fanshawe has a total of 3335 words
# The Seven Vagabonds (From "Twice Told Tales") has a total of 1202 words
# Septimius Felton has a total of 4222 words
# Fire Worship (From "Mosses From An Old Manse") has a total of 695 words
# Browne's Folly has a total of 305 words
# From Twice Told Tales has a total of 5664 words
# The Old Apple Dealer (From "Mosses From An Old Manse") has a total of 577 words
# Doctor Grimshawe's Secret has a total of 5463 words
# The Great Stone Face has a total of 2311 words
# Snow Flakes (From "Twice Told Tales") has a total of 503 words
# Fragments from The Journal of a Solitary Man has a total of 1104 words
# Mosses from an Old Manse and Other Stories has a total of 5341 words
# The Snow-Image has a total of 777 words
# Passages From the English Notebooks has a total of 8331 words
# Biographical Stories has a total of 1945 words
# The Three Golden Apples has a total of 1142 words
# The Hall of Fantasy (From "Mosses From An Old Manse") has a total of 860 words
# Sunday at Home (From "Twice Told Tales") has a total of 569 words
#
# Currently processing Jacob Abbott's works:
# *********************************************
# Rollo in Holland has a total of 2209 words
# Rollo at Work has a total of 1308 words
# The Teacher has a total of 3945 words
# Caleb in the Country has a total of 1497 words
# Richard I has a total of 3319 words
# Nero has a total of 3689 words
# Alexander the Great has a total of 3385 words
# Pyrrhus has a total of 3358 words
# King Alfred of England has a total of 3522 words
# Xerxes has a total of 3620 words
# Rollo's Philosophy has a total of 1365 words
# Margaret of Anjou has a total of 3130 words
# Rollo on the Atlantic has a total of 2399 words
# Georgie has a total of 473 words
# Richard II has a total of 3320 words
# Rollo's Experiments has a total of 1189 words
# Rollo in Rome has a total of 2069 words
# Rollo in Geneva has a total of 2149 words
# Cleopatra has a total of 3803 words
# Rollo in Scotland has a total of 2266 words
# Forests of Maine has a total of 1529 words
# Jonas on a Farm in Winter has a total of 1528 words
# William the Conqueror has a total of 3641 words
# Rollo in the Woods has a total of 367 words
# Rollo in London has a total of 2420 words
# Rollo's Museum has a total of 1644 words
# Rollo in Naples has a total of 2238 words
# Marco Paul's Voyages and Travels; Vermont has a total of 2022 words
# Mary Erskine has a total of 2021 words
# Richard III has a total of 3000 words
# Romulus has a total of 3718 words
# Charles I has a total of 3143 words
# Hannibal has a total of 3395 words
# Gentle Measures in the Management and Training of the Young has a total of 3890 words
# Rollo in Switzerland has a total of 2026 words
# Darius the Great has a total of 3517 words
# Mary Queen of Scots has a total of 3041 words
# Stuyvesant has a total of 1606 words
# Queen Elizabeth has a total of 3242 words
# Rollo in Paris has a total of 2280 words
# Rollo at Play has a total of 1601 words
# Cyrus the Great has a total of 3656 words
# Rollo on the Rhine has a total of 2378 words
# History of Julius Caesar has a total of 3396 words
# History of King Charles II of England has a total of 3545 words
# Peter the Great has a total of 3781 words
# Genghis Khan has a total of 3353 words
#
# Currently processing Edward Phillips Oppenheim's works:
# *********************************************
# The Zeppelin's Passenger has a total of 3264 words
# A People's Man has a total of 3911 words
# Anna the Adventuress has a total of 3215 words
# The Yellow Crayon has a total of 3496 words
# The Illustrious Prince has a total of 3797 words
# A Monk of Cruta has a total of 3534 words
# The Avenger has a total of 3462 words
# Mysterious Mr has a total of 4493 words
# The Wicked Marquis has a total of 4102 words
# The Hillman has a total of 3940 words
# The Survivor has a total of 3720 words
# Jeanne of the Marshes has a total of 3195 words
# The Great Prince Shan has a total of 3665 words
# The Moving Finger has a total of 3471 words
# Mr has a total of 4078 words
# The Double Life Of Mr has a total of 3511 words
# To Win the Love He Sought has a total of 3948 words
# An Amiable Charlatan has a total of 3150 words
# A Prince of Sinners has a total of 4136 words
# The Profiteers has a total of 3193 words
# Jacob's Ladder has a total of 3670 words
# A Lost Leader has a total of 3550 words
# The Traitors has a total of 3889 words
# The Great Impersonation has a total of 4022 words
# The Master Mummer has a total of 3474 words
# Mr has a total of 4078 words
# The Golden Web has a total of 3430 words
# The Lighted Way has a total of 3700 words
# The Lost Ambassador has a total of 3031 words
# The Malefactor has a total of 3517 words
# The Missioner has a total of 3839 words
# The Double Four has a total of 3521 words
# A Maker of History has a total of 3459 words
# Peter Ruff and the Double Four has a total of 4753 words
# The Black Box has a total of 4254 words
# The Devil's Paw has a total of 3738 words
# Havoc has a total of 3438 words
# The New Tenant has a total of 3993 words
# The Governors has a total of 2887 words
# The Pawns Count has a total of 3680 words
# A Millionaire of Yesterday has a total of 3941 words
# The Tempting of Tavernake has a total of 3928 words
# The Mischief Maker has a total of 3870 words
# The Vanished Messenger has a total of 3667 words
# The Kingdom of the Blind has a total of 3464 words
# The Box with the Broken Seals has a total of 3614 words
# The Cinema Murder has a total of 3781 words
# The Great Secret has a total of 3378 words
# The Double Traitor has a total of 3569 words
# The Evil Shepherd has a total of 3987 words
# Berenice has a total of 2595 words
# The Betrayal has a total of 3651 words
# Nobody's Man has a total of 4483 words
#
# Currently processing Anthony Trollope's works:
# *********************************************
# The Vicar of Bullhampton has a total of 5021 words
# The Mistletoe Bough has a total of 842 words
# The Three Clerks has a total of 6797 words
# La Vendée has a total of 5476 words
# The Golden Lion of Granpere has a total of 2558 words
# The Landleaguers has a total of 4155 words
# The Struggles of Brown, Jones, and Robinson has a total of 3414 words
# Life of Cicero Volume Two has a total of 4731 words
# An Eye for an Eye has a total of 2943 words
# Ayala's Angel has a total of 4809 words
# Thackeray has a total of 4054 words
# Mrs has a total of 1064 words
# Hunting Sketches has a total of 1668 words
# Dr has a total of 2766 words
# The Last Chronicle of Barset has a total of 6184 words
# Miss Sarah Jack, of Spanish Town, Jamaica has a total of 905 words
# The House of Heine Brothers, in Munich has a total of 846 words
# Phineas Finn has a total of 5528 words
# North America Volume 2 has a total of 5316 words
# Ralph the Heir has a total of 5289 words
# Sir Harry Hotspur of Humblethwaite has a total of 2731 words
# George Walker At Suez has a total of 860 words
# Kept in the Dark has a total of 2655 words
# The Relics of General Chasse has a total of 1072 words
# The O'Conors of Castle Conor from Tales from all Countries has a total of 780 words
# He Knew He Was Right has a total of 6531 words
# Returning Home has a total of 895 words
# North America Volume 1 has a total of 5582 words
# Is He Popenjoy? has a total of 4705 words
# Framley Parsonage has a total of 5655 words
# The Parson's Daughter of Oxney Colne has a total of 889 words
# The Warden has a total of 4109 words
# Aaron Trow has a total of 1103 words
# Mr has a total of 4744 words
# Rachel Ray has a total of 4158 words
# John Caldigate has a total of 5249 words
# Nina Balatka has a total of 2794 words
# Barchester Towers has a total of 6588 words
# Cousin Henry has a total of 2590 words
# The Kellys and the O'Kellys has a total of 5395 words
# The Fixed Period has a total of 3179 words
# Castle Richmond has a total of 5659 words
# Autobiography of Anthony Trollope has a total of 4480 words
# Linda Tressel has a total of 2754 words
# Phineas Redux has a total of 6105 words
# The Way We Live Now has a total of 6673 words
# The Eustace Diamonds has a total of 5793 words
# An Old Man's Love has a total of 2508 words
# The Courtship of Susan Bell has a total of 945 words
# The Prime Minister has a total of 6012 words
# The Bertrams has a total of 5939 words
# A Ride Across Palestine has a total of 1385 words
# Miss Mackenzie has a total of 4115 words
# Marion Fay has a total of 4991 words
# La Mere Bauche from Tales of All Countries has a total of 1154 words
# Can You Forgive Her? has a total of 6241 words
# The Macdermots of Ballycloran has a total of 5273 words
# Doctor Thorne has a total of 5804 words
# The Chateau of Prince Polignac has a total of 860 words
# The Small House at Allington has a total of 5675 words
# The Belton Estate has a total of 3980 words
# An Unprotected Female at the Pyramids has a total of 1169 words
# Life of Cicero Volume One has a total of 4960 words
# The Duke's Children has a total of 5102 words
# The Claverings has a total of 4738 words
# John Bull on the Guadalquivir from Tales from all Countries has a total of 1088 words
# Orley Farm has a total of 6102 words
# The American Senator has a total of 4933 words
# The Man Who Kept His Money In A Box has a total of 1043 words
# Lady Anna has a total of 3921 words
# Harry Heathcote of Gangoil has a total of 2277 words
#
# Currently processing Andrew Lang's works:
# *********************************************
# Homer and His Age has a total of 4428 words
# Angling Sketches has a total of 2907 words
# Modern Mythology has a total of 3578 words
# The Lilac Fairy Book has a total of 3468 words
# The Violet Fairy Book has a total of 3206 words
# A Collection of Ballads has a total of 2616 words
# The Puzzle of Dickens's Last Plot has a total of 1557 words
# The Book of Dreams and Ghosts has a total of 4277 words
# Myth, Ritual, and Religion, Vol has a total of 5361 words
# Myth, Ritual And Religion, Vol has a total of 5359 words
# Letters on Literature has a total of 3006 words
# Tales of Troy and Greece has a total of 3184 words
# Pickle the Spy has a total of 4192 words
# The Brown Fairy Book has a total of 3472 words
# How to Fail in Literature has a total of 1393 words
# Custom and Myth has a total of 4631 words
# The Clyde Mystery has a total of 2203 words
# He has a total of 1846 words
# The Pink Fairy Book has a total of 3117 words
# The Yellow Fairy Book has a total of 3535 words
# New Collected Rhymes has a total of 1095 words
# Shakespeare, Bacon and the Great Unknown has a total of 3645 words
# Old Friends - Essays in Epistolary Parody has a total of 3053 words
# Books and Bookmen has a total of 3355 words
# Andrew Lang's Introduction to The Compleat Angler has a total of 1496 words
# The Valet's Tragedy and Other Stories has a total of 4422 words
# Prince Prigio From "His Own Fairy Book" has a total of 1501 words
# Helen of Troy has a total of 2028 words
# A Monk of Fife has a total of 4029 words
# In the Wrong Paradise has a total of 4696 words
# Oxford has a total of 3277 words
# The Blue Fairy Book has a total of 4169 words
# John Knox and the Reformation has a total of 4449 words
# Lost Leaders has a total of 4203 words
# Prince Prigio has a total of 1442 words
# A Short History of Scotland has a total of 4604 words
# Sir Walter Scott and the Border Minstrelsy has a total of 2279 words
# Ballads in Blue China and Verses and Translations has a total of 1571 words
# Alfred Tennyson has a total of 4463 words
# Essays in Little has a total of 4704 words
# The Red Fairy Book has a total of 3704 words
# The Crimson Fairy Book has a total of 3151 words
# Rhymes a la Mode has a total of 1654 words
# Ban and Arriere Ban has a total of 1454 words
# The Mark Of Cain has a total of 4221 words
# The Making of Religion has a total of 5704 words
# The Disentanglers has a total of 5521 words
# James VI and the Gowrie Mystery has a total of 3420 words
# Historical Mysteries has a total of 4684 words
# The Library has a total of 3576 words
# Prince Ricardo of Pantouflia has a total of 1803 words
# The Grey Fairy Book has a total of 3245 words
# The Orange Fairy Book has a total of 3403 words
# Grass of Parnassus has a total of 1291 words
# The Gold Of Fairnilee has a total of 1069 words
# Letters to Dead Authors has a total of 3610 words
# Cock Lane and Common-Sense has a total of 5445 words
# Much Darker Days has a total of 1742 words
# The Arabian Nights Entertainments has a total of 3946 words
# Adventures among Books has a total of 5400 words
#
# Currently processing Robert Louis Stevenson's works:
# *********************************************
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 7 has a total of 6311 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 6 has a total of 5115 words
# Lay Morals has a total of 6143 words
# A Child's Garden of Verses, Verse 130 has a total of 943 words
# The Sea Fogs has a total of 597 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 4 has a total of 5603 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 5 has a total of 6153 words
# Father Damien has a total of 856 words
# The Strange Case Of Dr has a total of 2497 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 1 has a total of 7242 words
# Familiar Studies of Men & Books has a total of 6272 words
# A Lowden Sabbath Morn has a total of 229 words
# New Arabian Nights has a total of 5587 words
# Memoir of Fleeming Jenkin has a total of 4487 words
# Prince Otto has a total of 4255 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 2 has a total of 7824 words
# Edinburgh has a total of 2831 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 3 has a total of 6560 words
# The Merry Men has a total of 5376 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 22 has a total of 6911 words
# The Master of Ballantrae has a total of 4535 words
# A Child's Garden of Verses, Version 2 has a total of 837 words
# In the South Seas has a total of 6632 words
# The Waif Woman has a total of 680 words
# A Child's Garden of Verses, Version 3 has a total of 976 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 23 has a total of 6383 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 21 has a total of 5438 words
# A Child's Garden of Verses, Version 1 has a total of 795 words
# The Black Arrow has a total of 4162 words
# David Balfour, Second Part has a total of 4330 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 20 has a total of 6714 words
# Kidnapped has a total of 3763 words
# Tales and Fantasies has a total of 3863 words
# The Works of Robert Louis Stevenson - Swanston Edition, Volume 18 has a total of 7832 words
# ...
# The Letters of Charles Dickens Volume 2 has a total of 5476 words
# The Pickwick Papers has a total of 9182 words
# To be Read at Dusk has a total of 609 words
# The Cricket on the Hearth has a total of 2748 words
# The Wreck of the Golden Mary has a total of 1282 words
# A Message from the Sea has a total of 1277 words
# The Letters of Charles Dickens Volume 1 has a total of 5980 words
# Speeches: Literary and Social has a total of 4906 words
# Sketches of Young Couples has a total of 2232 words
# Hard Times has a total of 5480 words
# A Tale of Two Cities has a total of 6182 words
# The Battle of Life has a total of 2662 words
# Bleak House has a total of 9145 words
# Sunday Under Three Heads has a total of 1723 words
# The Perils of Certain English Prisoners has a total of 1533 words
# The Lamplighter has a total of 788 words
# Nicholas Nickleby has a total of 9299 words
# David Copperfield has a total of 8977 words
#
# Currently processing Charlotte Mary Yonge's works:
# *********************************************
# Love and Life has a total of 5550 words
# Young Folks' History of England has a total of 2308 words
# Two Penniless Princesses has a total of 4375 words
# Pioneers and Founders has a total of 6475 words
# The Heir of Redclyffe has a total of 6480 words
# Sowing and Sewing has a total of 1700 words
# The Herd Boy and His Hermit has a total of 3140 words
# Nuttie's Father has a total of 5256 words
# Young Folks' History of Rome has a total of 3272 words
# The Pigeon Pie has a total of 2158 words
# Beechcroft at Rockstone has a total of 5160 words
# A Reputed Changeling has a total of 5958 words
# Under the Storm has a total of 3603 words
# Stray Pearls has a total of 5455 words
# Dynevor Terrace (Vol has a total of 5571 words
# The Stokesley Secret has a total of 3054 words
# A Modern Telemachus has a total of 4123 words
# Abbeychurch has a total of 3399 words
# A Book of Golden Deeds has a total of 5581 words
# The Chaplet of Pearls has a total of 7402 words
# Aunt Charlotte's Stories of Greek History has a total of 3547 words
# Magnum Bonum has a total of 7521 words
# The Trial has a total of 6983 words
# Modern Broods has a total of 4287 words
# John Keble's Parishes has a total of 3813 words
# Little Lucy's Wonderful Globe has a total of 1309 words
# Grisly Grisell has a total of 4015 words
# Friarswood Post-Office has a total of 3043 words
# The Caged Lion has a total of 5535 words
# The Dove in the Eagle's Nest has a total of 5864 words
# Old Times at Otterbourne has a total of 1752 words
# Henrietta's Wish has a total of 4097 words
# The Carbonels has a total of 3430 words
# Heartsease has a total of 6707 words
# That Stick has a total of 3902 words
# Lady Hester, or Ursula's Narrative has a total of 2321 words
# The Two Sides of the Shield has a total of 4569 words
# More Bywords has a total of 4263 words
# The Daisy Chain has a total of 7519 words
# My Young Alcides has a total of 5300 words
# Hopes and Fears has a total of 9043 words
# The Long Vacation has a total of 4754 words
# Dynevor Terrace (Vol has a total of 5571 words
# The Pillars of the House, V1 has a total of 7270 words
# Cameos from English History, from Rollo to Edward II has a total of 6897 words
# Countess Kate has a total of 3106 words
# The Prince and the Page has a total of 4246 words
# Life of John Coleridge Patteson has a total of 7810 words
# The Young Step-Mother has a total of 7279 words
# Chantry House has a total of 5787 words
# The Little Duke has a total of 2555 words
# Scenes and Characters has a total of 3801 words
# History of France has a total of 2595 words
# The Lances of Lynwood has a total of 3413 words
# The Armourer's Prentices has a total of 5928 words
# Unknown to History has a total of 6487 words
# The Two Guardians has a total of 4593 words
# The Chosen People has a total of 3225 words
# The Three Brides has a total of 6171 words
# The Clever Woman of the Family has a total of 6658 words
#
# Currently processing Jack London's works:
# *********************************************
# Adventure has a total of 4421 words
# A Daughter of the Snows has a total of 5530 words
# Burning Daylight has a total of 5907 words
# Dutch Courage and Other Stories has a total of 2986 words
# The Scarlet Plague has a total of 1969 words
# Martin Eden has a total of 6701 words
# Moon-Face and Other Stories has a total of 4121 words
# The Call of the Wild has a total of 3010 words
# The Cruise of the Snark has a total of 5001 words
# The Faith of Men has a total of 3917 words
# The Acorn-Planter has a total of 830 words
# South Sea Tales has a total of 3485 words
# The Turtles of Tasman has a total of 3881 words
# John Barleycorn has a total of 4530 words
# The House of Pride has a total of 2798 words
# Michael, Brother of Jerry has a total of 5435 words
# The Jacket (The Star-Rover) has a total of 5869 words
# The Sea-Wolf has a total of 5500 words
# Children of the Frost has a total of 3378 words
# Lost Face has a total of 2919 words
# The Son of the Wolf has a total of 3844 words
# Jerry of the Islands has a total of 4689 words
# The God of His Fathers has a total of 3963 words
# The Strength of the Strong has a total of 3787 words
# Revolution and Other Essays has a total of 4750 words
# The Human Drift and Other Stories has a total of 2961 words
# The People of the Abyss has a total of 4637 words
# Smoke Bellew has a total of 4825 words
# Love of Life and Other Stories has a total of 3135 words
# The Cruise of the Dazzler has a total of 2816 words
# Before Adam has a total of 2829 words
# War of the Classes has a total of 3145 words
# Tales of the Fish Patrol has a total of 2455 words
# The Game has a total of 1739 words
# Stories of Ships and the Sea has a total of 1718 words
# Theft has a total of 2111 words
# The Red One has a total of 3469 words
# White Fang has a total of 4148 words
# The Mutiny of the Elsinore has a total of 5811 words
# The Road has a total of 3423 words
# A Son Of The Sun has a total of 3976 words
# The Valley of the Moon has a total of 7002 words
# On the Makaloa Mat has a total of 4211 words
# The Night-Born has a total of 3871 words
# When God Laughs and Other Stories has a total of 3800 words
# The Iron Heel has a total of 5117 words
# The Little Lady of the Big House has a total of 5880 words
# Brown Wolf and Other Jack London Stories has a total of 4087 words
#
# Currently processing Herbert George Wells's works:
# *********************************************
# The Research Magnificent has a total of 6508 words
# The Invisible Man has a total of 3493 words
# The War of the Worlds has a total of 4371 words
# The Island of Doctor Moreau has a total of 3366 words
# Anticipations has a total of 5739 words
# An Englishman Looks at the World has a total of 6430 words
# Twelve Stories and a Dream has a total of 4914 words
# Mankind in the Making has a total of 6175 words
# What is Coming? has a total of 4457 words
# In the Days of the Comet has a total of 5872 words
# The Sea Lady has a total of 2959 words
# Ann Veronica has a total of 5548 words
# Text Book of Biology, Part 1: Vertebrata has a total of 3243 words
# Marriage has a total of 7727 words
# The War in the Air has a total of 6117 words
# The World Set Free has a total of 5474 words
# The Wife of Sir Isaac Harman has a total of 6918 words
# The History of Mr has a total of 5370 words
# Soul of a Bishop has a total of 5219 words
# Certain Personal Matters has a total of 5279 words
# The Sleeper Awakes has a total of 4829 words
# Love and Mr has a total of 4575 words
# Floor Games; a companion volume to "Little Wars" has a total of 1094 words
# God The Invisible King has a total of 3559 words
# Tono Bungay has a total of 7553 words
# The Country of the Blind, And Other Stories has a total of 7681 words
# New Worlds For Old has a total of 5418 words
# The First Men In The Moon has a total of 4587 words
# The Red Room has a total of 640 words
# Kipps has a total of 6375 words
# The Salvaging Of Civilisation has a total of 3695 words
# Tales of Space and Time has a total of 5025 words
# The Door in the Wall And Other Stories has a total of 3511 words
# The Secret Places of the Heart has a total of 4122 words
# The New Machiavelli has a total of 8105 words
# When the Sleeper Wakes has a total of 5113 words
# The Passionate Friends has a total of 6232 words
# The Stolen Bacillus and Other Incidents has a total of 4156 words
# The Food of the Gods and How It Came to Earth has a total of 5216 words
# Boon, The Mind of the Race, The Wild Asses of the Devil, and The Last Trump has a total of 4517 words
# First and Last Things has a total of 4336 words
# Little Wars; a game for boys from twelve years of age to one hundred and fifty and for that more intelligent sort of girl who likes boys' games and books has a total of 1485 words
# In The Fourth Year has a total of 2836 words
# The Time Machine has a total of 2947 words
# Select Conversations with an Uncle has a total of 2377 words
# The Wheels of Chance has a total of 4159 words
# A Short History of the World has a total of 6154 words
# The Wonderful Visit has a total of 3114 words
# A Modern Utopia has a total of 6288 words
# Mr has a total of 7072 words
# War and the Future has a total of 4745 words
#
# Currently processing R M Ballantyne's works:
# *********************************************
# Wrecked but not Ruined has a total of 2572 words
# Jarwin and Cuffy has a total of 2833 words
# Martin Rattler has a total of 4002 words
# Blue Lights has a total of 4892 words
# The Walrus Hunters has a total of 4569 words
# The Cannibal Islands has a total of 2451 words
# Saved by the Lifeboat has a total of 2378 words
# Post Haste has a total of 5229 words
# Away in the Wilderness has a total of 2103 words
# Fighting the Whales has a total of 1751 words
# Twice Bought has a total of 3974 words
# The Middy and the Moors has a total of 3715 words
# The Life of a Ship has a total of 724 words
# The Madman and the Pirate has a total of 3426 words
# Under the Waves has a total of 5050 words
# Silver Lake has a total of 2655 words
# Hunting the Lions has a total of 2404 words
# The Wild Man of the West has a total of 4865 words
# Gascoyne, the Sandal-Wood Trader has a total of 4702 words
# My Doggie and I has a total of 2963 words
# The Story of the Rock has a total of 2341 words
# The Young Trawler has a total of 4447 words
# The Ocean and its Wonders has a total of 3285 words
# Sunk at Sea has a total of 2534 words
# Hudson Bay has a total of 5097 words
# Handbook to the new Gold-fields has a total of 2823 words
# The Island Queen has a total of 3736 words
# In the Track of the Troops has a total of 5162 words
# Red Rooney has a total of 4724 words
# The Lonely Island has a total of 4733 words
# The Dog Crusoe and his Master has a total of 4489 words
# The Rover of the Andes has a total of 5046 words
# The Coxswain's Bride has a total of 3632 words
# Fort Desolation has a total of 1864 words
# The Lighthouse has a total of 4654 words
# The Lifeboat has a total of 4618 words
# Ungava has a total of 5446 words
# The World of Ice has a total of 4502 words
# Digging for Gold has a total of 2499 words
# The Lively Poll has a total of 2630 words
# Chasing the Sun has a total of 2327 words
# The Iron Horse has a total of 4955 words
# The Eagle Cliff has a total of 4445 words
# Jeff Benson, or the Young Coastguardsman has a total of 1901 words
# Fighting the Flames has a total of 4771 words
# Lost in the Forest has a total of 2647 words
# The Pirate City has a total of 5005 words
# Man on the Ocean has a total of 3741 words
# The Garret and the Garden has a total of 2655 words
# Erling the Bold has a total of 4701 words
# Battles with the Sea has a total of 2199 words
# Hunted and Harried has a total of 3474 words
# Life in the Red Brigade has a total of 2647 words
# The Hot Swamp has a total of 4350 words
# Personal Reminiscences in Book Making has a total of 4059 words
# Blown to Bits has a total of 5025 words
# The Pioneers has a total of 2465 words
# Over the Rocky Mountains has a total of 2589 words
# The Young Fur Traders has a total of 5680 words
# Shifting Winds has a total of 4800 words
# The Battery and the Boiler has a total of 4958 words
# The Thorogood Family has a total of 2145 words
# Fast in the Ice has a total of 2011 words
# The Battle and the Breeze has a total of 2332 words
# The Floating Light of the Goodwin Sands has a total of 5077 words
# Rivers of Ice has a total of 5131 words
# The Red Man's Revenge has a total of 4386 words
# The Settler and the Savage has a total of 5368 words
# The Prairie Chief has a total of 3461 words
# Charlie to the Rescue has a total of 4816 words
# The Norsemen in the West has a total of 4337 words
# The Crew of the Water Wagtail has a total of 3815 words
# Black Ivory has a total of 5082 words
# The Big Otter has a total of 4917 words
# Philosopher Jack has a total of 3428 words
# Six Months at the Cape has a total of 3600 words
# Freaks on the Fells has a total of 4629 words
# Up in the Clouds has a total of 2731 words
# Deep Down, a Tale of the Cornish Mines has a total of 5243 words
# The Gorilla Hunters has a total of 4602 words
# Dusty Diamonds Cut and Polished has a total of 4924 words
# The Fugitives has a total of 4891 words
# The Coral Island has a total of 4518 words
# The Giant of the North has a total of 4850 words
# The Red Eric has a total of 5069 words
# The Buffalo Runners has a total of 4734 words
# The Butterfly's Ball has a total of 652 words
# The Golden Dream has a total of 5249 words
#
# Currently processing Mark Twain's works:
# *********************************************
# The Man That Corrupted Hadleyburg and Other Stories has a total of 6460 words
# Tom Sawyer, Detective has a total of 1302 words
# The $30,000 Bequest and Other Stories has a total of 5647 words
# Some Rambling Notes of an Idle Excursion has a total of 2036 words
# A Burlesque Autobiography has a total of 783 words
# The American Claimant has a total of 4239 words
# Editorial Wild Oats has a total of 1447 words
# Chapters from My Autobiography has a total of 5748 words
# Fenimore Cooper's Literary Offences has a total of 713 words
# The Letters Of Mark Twain, Complete has a total of 8557 words
# What Is Man? And Other Essays has a total of 5587 words
# A Double Barrelled Detective Story has a total of 1888 words
# Life On The Mississippi, Complete has a total of 6985 words
# The Adventures of Tom Sawyer, Complete has a total of 4312 words
# Mark Twain's Speeches has a total of 4747 words
# Christian Science has a total of 4354 words
# The Innocents Abroad has a total of 8570 words
# A Connecticut Yankee in King Arthur's Court, Complete has a total of 6037 words
# Is Shakespeare Dead? has a total of 2330 words
# Captain Stormfield's Visit to Heaven has a total of 1269 words
# Roughing It has a total of 8095 words
# The Tragedy of Pudd'nhead Wilson has a total of 3741 words
# Personal Recollections of Joan of Arc, Volume 1 has a total of 4401 words
# Extracts From Adam's Diary has a total of 535 words
# Sketches New and Old, Complete has a total of 6367 words
# Tom Sawyer Abroad has a total of 1723 words
# The Stolen White Elephant has a total of 1042 words
# A Dog's Tale has a total of 579 words
# Personal Recollections of Joan of Arc, Volume 2 has a total of 4055 words
# 1601 has a total of 1653 words
# A Tramp Abroad has a total of 7553 words
# The Facts Concerning The Recent Carnival Of Crime In Connecticut has a total of 962 words
# The Curious Republic of Gondour and Other Whimsical Sketches has a total of 2269 words
# Essays on Paul Bourget has a total of 1346 words
# In Defense of Harriet Shelley has a total of 1756 words
# Goldsmith's Friend Abroad Again has a total of 941 words
# Alonzo Fitz and Other Stories has a total of 2962 words
# The Prince and The Pauper, Complete has a total of 4749 words
# Following the Equator, Complete has a total of 8545 words
# Eve's Diary, Complete has a total of 753 words
# A Horse's Tale has a total of 1612 words
# Those Extraordinary Twins has a total of 2137 words
# Adventures of Huckleberry Finn, Complete has a total of 3267 words
# On the Decay of the Art of Lying has a total of 423 words
# The Mysterious Stranger and Other Stories has a total of 2990 words
# The Treaty With China, its Provisions Explained has a total of 1080 words
# How Tell a Story and Others has a total of 917 words
#
# CPU times: user 3h 49min 52s, sys: 1min 48s, total: 3h 51min 41s
# Wall time: 4h 7min 26s

# %%
# Rearrange works.csv, placeofbirth_df.csv, result_df.csv, and works.csv in a folder called author-data

# If the folder that stores the author's data doesn't exist, create it
if os.path.isdir('./data/author-data') == False:
    print("The folder author-data has been created: ./data/author-data/")
    os.mkdir('./data/author-data')
else:
    print("Folder author-data already exists")
# Out:
# The folder author-data has been created: ./data/author-data/

# %%
import shutil

# %%
# If file ends with .csv , move it to author-data
for csv in os.listdir('./data'):
    if csv == 'placeofbirth_df.csv':
        shutil.copy2(f'./data/{csv}', f'./data/author-data/{csv}')
    elif csv == 'works.csv':
        pass
    elif csv.endswith('.csv'):
        os.rename(f'./data/{csv}', f'./data/author-data/{csv}')
        print(f"{csv} moved to author-data")
# Out:
# author_list.csv moved to author-data
# result_df.csv moved to author-data
